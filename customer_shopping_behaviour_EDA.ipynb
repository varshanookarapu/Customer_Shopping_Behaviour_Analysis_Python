# %% [markdown]
# <a href="https://colab.research.google.com/github/varshanookarapu/Customer_Shopping_Behaviour_Analysis_Python/blob/main/customer_shopping_behaviour_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The agenda of this project is to first understand the problem statement,then analyze customer shopping behavior in detail, clean the data, and perform exploratory data analysis (EDA) and  document the data-cleaning steps along with the logical thought process behind each step.
#
#
# Link  :https://www.youtube.com/watch?v=5PrZvPeUw60

# %% [markdown]
# ## Problem Statement
#  A leading retail company wants to better understand its customers’ shopping behavior in order improve sales, customer satisfaction, and long-term loyalty. The management team has noticed changes in purchasing patterns across demographics, product categories, and sales channels (online vs. offline). They are particularly interested in uncovering which factors, such as discounts, reviews, seasons, or payment preferences, drive consumer decisions and repeat purchases.
# You are tasked with analyzing the company’s consumer behavior dataset to answer the following overarching business question:
#
#
# **“How can the company leverage consumer shopping data to identify trends, improve customer engagement, and optimize marketing and product strategies?”**

# %%
from google.colab import files  ## so bascially i do not have jupyter notebook on my computer and I am using google collab , to get the file , I had to use the import files library and upload the csv file.

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b443300f-3b41-477e-ae32-ea4217990ee6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b443300f-3b41-477e-ae32-ea4217990ee6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd;
import numpy as np;

# %%
customer_behaviour_df = pd.read_csv("customer_shopping_behavior.csv")  ## Finally I got the file in a data frame now .

# %% [markdown]
# ###Cheklist For Data Cleaning
#
# 1.Check the shape of the data (total rows and total columns)
#
# 2.Check for the column names if they are copacetic and update the case and the format if needed
#
# 3.Check for missing values or null values in every column
#
# 4.Count the missing values or null values and determine if you need to impute the data ( by using mean,median, first up or first down approach )
#
# 5.Remove the duplicates
#
# 6.Check the data types of every column and convert them where needed
#
# 7.Check the statistical summary of every data column
#
# 8. Add in new columns if needed based on the existing columns

# %%
## Checking the shape of data
customer_behaviour_df.shape
# Out:
# (3900, 18)

# %%
## Checking all the info - gives more detailed summary with null counts
customer_behaviour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
# Checking the datatypes - No data type converstion are required
customer_behaviour_df.dtypes
# Out:
# Customer ID                 int64
# Age                         int64
# Gender                     object
# Item Purchased             object
# Category                   object
# Purchase Amount (USD)       int64
# Location                   object
# Size                       object
# Color                      object
# Season                     object
# Review Rating             float64
# Subscription Status        object
# Shipping Type              object
# Discount Applied           object
# Promo Code Used            object
# Previous Purchases          int64
# Payment Method             object
# Frequency of Purchases     object
# dtype: object

# %%
## Checking for missing or null values in every column
customer_behaviour_df.isna().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %%
## Its is evident that Review column has 37 null values , I will update those with the rating "unknown"
##customer_behaviour_df["Review Rating"] = customer_behaviour_df["Review Rating"].fillna("Unknown")
##customer_behaviour_df[customer_behaviour_df["Review Rating"] == "unknown"]
## It did cross my mind to update the review rating to zero but then rating 0 means its bad so I just chose to make it unknown.

# %%
#At first, my intuition was to replace the missing values with "Unknown", since there are only 37 missing values out of 3,900. However, after referring to the video, I realized that imputing the missing values
# using the median is a better approach. Another good point he made was regarding why we choose mean or median for imputation in the first place. In this case, we prefer the median over the mean because the mean can
#be significantly affected by outliers, which can skew the data distribution. Therefore, using the median provides a more robust estimate. Even with the median, he did not simply calculate the median of all the ratings
# and use that value to replace every missing entry. Instead, he calculated the median rating for each category and used the corresponding category-level median to fill in the missing values.
#This is a much more logical and meaningful way to impute the data because the typical rating can vary across different categories.
#Overall, I think this is a really good approach to handling the missing values in the dataset.

# %%
#Based on the above observation , I will now try to find median review rating for every category.

# Another important distinction is median() reduces the data , transform("median") will keep the data set as is and then update the values

customer_behaviour_df.groupby("Category")["Review Rating"].median().reset_index(name="Median Review Rating")
# Out:
#       Category  Median Review Rating
# 0  Accessories                   3.8
# 1     Clothing                   3.7
# 2     Footwear                   3.8
# 3    Outerwear                   3.8

# %%
## Now i will replace the median review rating in all the missing values .

customer_behaviour_df["Review Rating"] = customer_behaviour_df["Review Rating"].fillna(customer_behaviour_df.groupby("Category")["Review Rating"].transform("median"))

# %%
## Now I will check for duplicates and drop them  - bascially i am using duplicated function with sum to check and count the duplicates and if there are any duplicates i will use drop_duplicates() to remove them. and then put it in another df and check the shape of the data .
customer_behaviour_df.duplicated().sum()
## for now there's no duplicates in the data
# Out:
# np.int64(0)

# %%
## Statistical Summary
customer_behaviour_df.describe(include="all")
# Out:
#         Customer ID          Age Gender Item Purchased  Category  \
# count   3900.000000  3900.000000   3900           3900      3900
# unique          NaN          NaN      2             25         4
# top             NaN          NaN   Male         Blouse  Clothing
# freq            NaN          NaN   2652            171      1737
# mean    1950.500000    44.068462    NaN            NaN       NaN
# std     1125.977353    15.207589    NaN            NaN       NaN
# min        1.000000    18.000000    NaN            NaN       NaN
# 25%      975.750000    31.000000    NaN            NaN       NaN
# 50%     1950.500000    44.000000    NaN            NaN       NaN
# 75%     2925.250000    57.000000    NaN            NaN       NaN
# max     3900.000000    70.000000    NaN            NaN       NaN
#
#         Purchase Amount (USD) Location  Size  Color  Season  Review Rating  \
# count             3900.000000     3900  3900   3900    3900    3863.000000
# ...

# %%
## As we have seen above the column names have spaces in them  for better readability I will now convert those column names to lower and replace spaces with underscores


customer_behaviour_df.columns = customer_behaviour_df.columns.str.lower().str.replace(" ","_")

customer_behaviour_df= customer_behaviour_df.rename(

    {
        "purchase_amount_(usd)": "purchase_amount_usd",
    }
    )

# %%
customer_behaviour_df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_(usd)', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %%
customer_behaviour_df.groupby("frequency_of_purchases").count()["customer_id"]
# Out:
# frequency_of_purchases
# Annually          572
# Bi-Weekly         547
# Every 3 Months    584
# Fortnightly       542
# Monthly           553
# Quarterly         563
# Weekly            539
# Name: customer_id, dtype: int64

# %%
## Mapping Days to Frequency purchases

frequency_mapping = {

  "Annually" : 365,
  "Bi-Weekly" : 14,
  "Every 3 Months" : 90,
  "Fortnightly" : 14,
  "Monthly" : 30,
  "Quarterly" : 90,
  "Weekly" : 7

}

customer_behaviour_df["purchase_frequency_days"] = customer_behaviour_df["frequency_of_purchases"].map(frequency_mapping)

customer_behaviour_df.head()
# Out:
#    customer_id  age gender item_purchased  category  purchase_amount_(usd)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         location size      color  season  review_rating subscription_status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
## creating an age group column

age_group_list = ["Young_Adult","Adult","Middle Aged","Senior"]


customer_behaviour_df["age_group"] = pd.qcut(customer_behaviour_df["age"],q=4,labels=age_group_list)


customer_behaviour_df.head()
# Out:
#    customer_id  age gender item_purchased  category  purchase_amount_(usd)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         location size      color  season  review_rating subscription_status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
## Removing unnecessary columns

# (customer_behaviour_df["discount_applied"] == customer_behaviour_df["promo_code_used"]).all()

# customer_behaviour_df = customer_behaviour_df.drop(columns=["promo_code_used"])
customer_behaviour_df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_(usd)', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases', 'purchase_frequency_days', 'age_group'],
#       dtype='object')

# %% [markdown]
# After the above data cleaning steps, I have ensured there are no null values / duplicates in the data set and all the data types are accurate ,and will now procced to further analysis.

# %% [markdown]
# Based on this  " The management team has noticed changes in purchasing patterns across demographics, product categories, and sales channels (online vs. offline)"
#
# The questions I can analyse are
#
# 1.How many male and female customers are there in the dataset
#
# 2.Out of those how many purchased online / offilne ( sales channels)
#
# 3.Who among all the customers have more previous purchases top 5 , under which season and  check the discouts , promo codes , shipping type
#
# 4.Finding seasonal purchases , like How many customers purchased  in every season
#
# 5.Customers purchase frequency analysis
#
# 6.Which item has more reviews and how many people purchased it
